# %%
from nltk.corpus import framenet as fn

for i in range(100):
    print fn.sents()[i]['frameAnnotation']
    print '\n====================\n'
# Out:
# annotation set (2387348):
#
# [status] MANUAL
#
# [LU] (14930) empathize.v in Others_situation_as_stimulus
#
# [frame] (2048) Others_situation_as_stimulus
#
# [GF] 1 relation
#
# [PT] 1 phrase
#
# [text] + [Target] + [FE]
#
# It is easy to empathize with foster parents duped into incubating
#               ********* -----------------------------------------
#                         Other
#
#  the cuckoo 's eggs .
# -------------------
#                     [Experiencer:CNI]
#
#
#
#
# ...
#
# annotation set (2387358):
#
# [status] MANUAL
#
# [LU] (14930) empathize.v in Others_situation_as_stimulus
#
# [frame] (2048) Others_situation_as_stimulus
#
# [GF] 2 relations
#
# [PT] 2 phrases
#
# [text] + [Target] + [FE] + [FE2]
#
# Nigel could empathize with that .
# -----       ********* ---------
# Exper                 Situation
#                       ---------
#                       Other
#  (Exper=Experiencer)
#
#
#
# ...
#
# annotation set (2387362):
#
# [status] MANUAL
#
# ...
