# %% [markdown]
# ## STATISTICS

# %% [markdown]
# #### Target->Arg/Frame structures
#
# * the majority of the distinct tar-frame structures are singletons (Fig 1, print 1)

# %%
# Fig 1

# %%
# Print 1
# Out:
# cut at 1000 = 12
#
# ...
#
# cut at 500 = 34
#
# ...
#
# cut at 200 = 151
#
# ...
#
# cut at 100 = 340
#
# ...
#
# cut at 50 = 692
#
# ...
#
# cut at 20 = 1602
#
# ...
#
# cut at 10 = 2767
#
# ...
#
# cut at 5 = 4543
#
# ...
#
# cut at 2 = 7713
#
# ...
#
# cut at 1 = 10773
#
# ...

# %% [markdown]
# #### Targets
#
# * sparse and diverse in frame-evocation (Fig 2, 3)

# %%
# Fig 2

# %%
# Fig 3

# %% [markdown]
# #### Frames
#
# * pretty sparse (Fig 4, 5; Print 2).

# %%
# Fig 4

# %%
# Fig 5

# %%
# Print 2: in total there is 1000+ frames, half appear less than 2.
# Out:
# cut at 1000 = 37
# cut at 500 = 97
# cut at 200 = 241
# cut at 100 = 430
# cut at 50 = 627
# cut at 20 = 815
# cut at 10 = 890
# cut at 5 = 939
# cut at 2 = 988
